# %%
# !pip install plotly
# !pip install cufflinks
# Out:
# ...
#      ---------------------------------------- 0.0/81.7 kB ? eta -:--:--
#      ------------------- ------------------ 41.0/81.7 kB 653.6 kB/s eta 0:00:01
#      -------------------------------------- 81.7/81.7 kB 916.7 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for cufflinks: filename=cufflinks-0.17.3-py3-none-any.whl size=68725 sha256=9250034be9bfe22d2ffc0084930d2aa8f37f7fdef71a2950f87fe418a6d3ab37
#   Stored in directory: c:\users\arvin\appdata\local\pip\cache\wheels\c3\bf\8f\afa0730b29e347e8c1071049f89748c1262e7a14a838820ae6
# Successfully built cufflinks
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !pip install plotly
# !pip install cufflinks

# %%
df=pd.DataFrame(np.random.rand(1000,1),index=pd.date_range('2023-08-25', periods=1000),columns=['1'])

# %%
df
# Out:
#                    1
# 2023-08-25  0.296431
# 2023-08-26  0.289169
# 2023-08-27  0.279510
# 2023-08-28  0.445829
# 2023-08-29  0.802506
# ...              ...
# 2026-05-16  0.740927
# 2026-05-17  0.759687
# 2026-05-18  0.299824
# 2026-05-19  0.848912
# 2026-05-20  0.405036
#
# [1000 rows x 1 columns]

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.cumsum().plot()
# Out:
# <Axes: >

# %%
df['data1'] = df.cumsum()

# %%
df['data23']=df['1'].apply(lambda x:x*2)

# %%
df
# Out:
#                    1       data1    data23
# 2023-08-25  0.296431    0.296431  0.592862
# 2023-08-26  0.289169    0.585600  0.578338
# 2023-08-27  0.279510    0.865110  0.559021
# 2023-08-28  0.445829    1.310939  0.891659
# 2023-08-29  0.802506    2.113445  1.605011
# ...              ...         ...       ...
# 2026-05-16  0.740927  510.679940  1.481854
# 2026-05-17  0.759687  511.439628  1.519375
# 2026-05-18  0.299824  511.739452  0.599648
# 2026-05-19  0.848912  512.588364  1.697824
# 2026-05-20  0.405036  512.993400  0.810072
#
# [1000 rows x 3 columns]

# %%
df.plot()
# Out:
# <Axes: >

# %%
df1=sns.load_dataset('iris')

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df1.plot()
# Out:
# <Axes: >

# %%
gf=df1.plot(title= "irish data ")
gf.set_xlabel('x')
gf.set_ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
df1.iloc[0][0:4].plot()
# Out:
# <Axes: >

# %%
df1.iloc[0][0:4]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: object

# %%
df1.iloc[0:4]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa

# %%
df1.iloc[0][0:4].plot(kind='bar')
# Out:
# <Axes: >

# %%
titanic=sns.load_dataset('titanic')

# %%
titanic['pclass'].plot()
# Out:
# <Axes: >

# %%
titanic['pclass'].plot(kind='bar')
# Out:
# <Axes: >

# %%
df3 = pd.DataFrame(np.random.rand(10,4) , columns= ['a' , 'b' , 'c' , 'd'])

# %%
df3
# Out:
#           a         b         c         d
# 0  0.416780  0.733062  0.666952  0.523233
# 1  0.770052  0.814135  0.935671  0.931083
# 2  0.908647  0.004670  0.884921  0.906699
# 3  0.763549  0.579017  0.164963  0.381843
# 4  0.200890  0.260582  0.729059  0.880073
# 5  0.126591  0.467608  0.624710  0.063644
# 6  0.552320  0.151044  0.632761  0.188266
# 7  0.905968  0.315014  0.069835  0.613670
# 8  0.379014  0.665237  0.988759  0.220225
# 9  0.429191  0.646436  0.840851  0.935068

# %%
df3['a'].plot()
# Out:
# <Axes: >

# %%
df3.plot(kind='bar')
# Out:
# <Axes: >

# %%
df3.plot.barh()
# Out:
# <Axes: >

# %%
df3.plot.hist() # x-axis in histogram represents a range & y-axis represents frequency
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1.plot.hist(by="sepal_width")
# Out:
# array([<Axes: title={'center': '2.0'}, ylabel='Frequency'>,
#        <Axes: title={'center': '2.2'}, ylabel='Frequency'>,
#        <Axes: title={'center': '2.3'}, ylabel='Frequency'>,
#        <Axes: title={'center': '2.4'}, ylabel='Frequency'>,
#        <Axes: title={'center': '2.5'}, ylabel='Frequency'>,
#        <Axes: title={'center': '2.6'}, ylabel='Frequency'>,
#        <Axes: title={'center': '2.7'}, ylabel='Frequency'>,
#        <Axes: title={'center': '2.8'}, ylabel='Frequency'>,
#        <Axes: title={'center': '2.9'}, ylabel='Frequency'>,
#        <Axes: title={'center': '3.0'}, ylabel='Frequency'>,
#        <Axes: title={'center': '3.1'}, ylabel='Frequency'>,
#        <Axes: title={'center': '3.2'}, ylabel='Frequency'>,
#        <Axes: title={'center': '3.3'}, ylabel='Frequency'>,
#        <Axes: title={'center': '3.4'}, ylabel='Frequency'>,
#        <Axes: title={'center': '3.5'}, ylabel='Frequency'>,
#        <Axes: title={'center': '3.6'}, ylabel='Frequency'>,
# ...

# %%
df1['sepal_length'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1.plot(kind='hist', stacked= True, bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1.plot(kind = 'hist' , stacked = True , bins = 100 , figsize = (10,10) , title = "histogram of iris")
# Out:
# <Axes: title={'center': 'histogram of iris'}, ylabel='Frequency'>

# %%
df1.plot(kind = 'hist' , stacked = True , bins = 100 , figsize = (10,10) , title = "histogram of iris" ,orientation = 'horizontal')
# Out:
# <Axes: title={'center': 'histogram of iris'}, xlabel='Frequency'>

# %%
df1.hist(figsize= (10,10) , color = 'r' , alpha  = .9)
# Out:
# array([[<Axes: title={'center': 'sepal_length'}>,
#         <Axes: title={'center': 'sepal_width'}>],
#        [<Axes: title={'center': 'petal_length'}>,
#         <Axes: title={'center': 'petal_width'}>]], dtype=object)

# %%
df1.hist(figsize= (10,10) , color = 'r' , alpha  = .2)
# Out:
# array([[<Axes: title={'center': 'sepal_length'}>,
#         <Axes: title={'center': 'sepal_width'}>],
#        [<Axes: title={'center': 'petal_length'}>,
#         <Axes: title={'center': 'petal_width'}>]], dtype=object)

# %%
df1.plot.scatter(x='sepal_width',y='petal_width')
# Out:
# <Axes: xlabel='sepal_width', ylabel='petal_width'>

# %%
df1.plot.scatter(x='sepal_length',y='petal_width')
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_width'>

# %%
df1.plot.scatter(x='sepal_length',y='petal_width', c='petal_length')
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_width'>

# %%
df1.plot.scatter(x  ='sepal_length' , y  = 'sepal_width', label = 'sudh' ,s = 100 ,c = 'petal_width')
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
df1.plot.hexbin(x  ='sepal_length' , y  = 'sepal_width', label = 'sudh' ,gridsize = 10)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
df
# Out:
#                    1       data1    data23
# 2023-08-25  0.296431    0.296431  0.592862
# 2023-08-26  0.289169    0.585600  0.578338
# 2023-08-27  0.279510    0.865110  0.559021
# 2023-08-28  0.445829    1.310939  0.891659
# 2023-08-29  0.802506    2.113445  1.605011
# ...              ...         ...       ...
# 2026-05-16  0.740927  510.679940  1.481854
# 2026-05-17  0.759687  511.439628  1.519375
# 2026-05-18  0.299824  511.739452  0.599648
# 2026-05-19  0.848912  512.588364  1.697824
# 2026-05-20  0.405036  512.993400  0.810072
#
# [1000 rows x 3 columns]

# %%
d=df.iloc[0]

# %%
d.plot.pie()
# Out:
# <Axes: ylabel='2023-08-25 00:00:00'>

# %%
df1.head(3)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa

# %%
df1.head(3).T
# Out:
#                    0       1       2
# sepal_length     5.1     4.9     4.7
# sepal_width      3.5     3.0     3.2
# petal_length     1.4     1.4     1.3
# petal_width      0.2     0.2     0.2
# species       setosa  setosa  setosa

# %%
dd=df1.head(3).T

# %%
df1.plot.pie()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 df1.plot.pie()
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_core.py:1611, in PlotAccessor.pie(self, **kwargs)
#    1560 """
#    1561 Generate a pie plot.
#    1562
#    (...)
#    1604     >>> plot = df.plot.pie(subplots=True, figsize=(11, 6))
#    1605 """
#    1606 if (
#    1607     isinstance(self._parent, ABCDataFrame)
#    1608     and kwargs.get("y", None) is None
#    1609     and not kwargs.get("subplots", False)
#    1610 ):
# -> 1611     raise ValueError("pie requires either y column or 'subplots=True'")
#    1612 return self(kind="pie", **kwargs)
#
# ValueError: pie requires either y column or 'subplots=True'

# %%
dd.iloc[:4].plot.pie(subplots=True, figsize= (20,20),fontsize=20, autopct='%2f')

# %%
pd.plotting.scatter_matrix()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 pd.plotting.scatter_matrix()
#
# TypeError: scatter_matrix() missing 1 required positional argument: 'frame'

# %%
pd.plotting.scatter_matrix(df1)
# Out:
# array([[<Axes: xlabel='sepal_length', ylabel='sepal_length'>,
#         <Axes: xlabel='sepal_width', ylabel='sepal_length'>,
#         <Axes: xlabel='petal_length', ylabel='sepal_length'>,
#         <Axes: xlabel='petal_width', ylabel='sepal_length'>],
#        [<Axes: xlabel='sepal_length', ylabel='sepal_width'>,
#         <Axes: xlabel='sepal_width', ylabel='sepal_width'>,
#         <Axes: xlabel='petal_length', ylabel='sepal_width'>,
#         <Axes: xlabel='petal_width', ylabel='sepal_width'>],
#        [<Axes: xlabel='sepal_length', ylabel='petal_length'>,
#         <Axes: xlabel='sepal_width', ylabel='petal_length'>,
#         <Axes: xlabel='petal_length', ylabel='petal_length'>,
#         <Axes: xlabel='petal_width', ylabel='petal_length'>],
#        [<Axes: xlabel='sepal_length', ylabel='petal_width'>,
#         <Axes: xlabel='sepal_width', ylabel='petal_width'>,
#         <Axes: xlabel='petal_length', ylabel='petal_width'>,
# ...

# %%
pd.plotting.scatter_matrix(df1 , figsize = (10,10),diagonal='kde')
# Out:
# array([[<Axes: xlabel='sepal_length', ylabel='sepal_length'>,
#         <Axes: xlabel='sepal_width', ylabel='sepal_length'>,
#         <Axes: xlabel='petal_length', ylabel='sepal_length'>,
#         <Axes: xlabel='petal_width', ylabel='sepal_length'>],
#        [<Axes: xlabel='sepal_length', ylabel='sepal_width'>,
#         <Axes: xlabel='sepal_width', ylabel='sepal_width'>,
#         <Axes: xlabel='petal_length', ylabel='sepal_width'>,
#         <Axes: xlabel='petal_width', ylabel='sepal_width'>],
#        [<Axes: xlabel='sepal_length', ylabel='petal_length'>,
#         <Axes: xlabel='sepal_width', ylabel='petal_length'>,
#         <Axes: xlabel='petal_length', ylabel='petal_length'>,
#         <Axes: xlabel='petal_width', ylabel='petal_length'>],
#        [<Axes: xlabel='sepal_length', ylabel='petal_width'>,
#         <Axes: xlabel='sepal_width', ylabel='petal_width'>,
#         <Axes: xlabel='petal_length', ylabel='petal_width'>,
# ...

# %%
df1.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df1.plot()
# Out:
# <Axes: >

# %%
df1['sepal_length'].plot(style = 'r*' , legend = True , label = "Avi" )
# Out:
# <Axes: >

# %%
from plotly.offline import iplot
import plotly as py
import plotly.tools as tls
import cufflinks as cf
# Out:
# C:\Users\arvin\anaconda3\Lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning:
#
# Blowfish has been deprecated

# %%
py.__version__
# Out:
# '5.9.0'

# %%
df1.plot()
# Out:
# <Axes: >

# %%
df1.iplot()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\cufflinks\plotlytools.py:1431, in iplot(figure, validate, sharing, filename, online, asImage, asUrl, asPlot, dimensions, display_image, **kwargs)
#    1430 try:
# -> 1431 	import chart_studio.plotly as py
#    1432 except:
#
# ModuleNotFoundError: No module named 'chart_studio'
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 df1.iplot()
#
# ...

# %%
py.offline.init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
# ...

# %%
df1.iplot()
# Out:
# <div>                            <div id="721360a7-bba9-459d-be98-1c38c291ee15" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
titanic.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
titanic.iplot(kind='scatter',y='age', x='fare',  mode='markers', xTitle='fare', yTitle='age')
# Out:
# <div>                            <div id="476f5753-c56b-458f-9050-27db63ec28d2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
titanic.iplot(kind='scatter', x='pclass', y='age', mode='markers')
# Out:
# <div>                            <div id="ae1b25d5-a5c7-44af-ac56-602ec03cb07b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
cf.getTheme()
# Out:
# {'colorscale': 'original',
#  'linewidth': 1.3,
#  'bargap': 0.01,
#  'layout': {'legend': {'bgcolor': '#F5F6F9', 'font': {'color': '#4D5663'}},
#   'paper_bgcolor': '#F5F6F9',
#   'plot_bgcolor': '#F5F6F9',
#   'yaxis': {'tickfont': {'color': '#4D5663'},
#    'gridcolor': '#E1E5ED',
#    'titlefont': {'color': '#4D5663'},
#    'zerolinecolor': '#E1E5ED',
#    'showgrid': True},
#   'xaxis': {'tickfont': {'color': '#4D5663'},
#    'gridcolor': '#E1E5ED',
#    'titlefont': {'color': '#4D5663'},
#    'zerolinecolor': '#E1E5ED',
#    'showgrid': True},
#   'titlefont': {'color': '#4D5663'}},
#  'annotations': {'fontcolor': '#4D5663', 'arrowcolor': '#9499A3'},
#  '3d': {'yaxis': {'gridcolor': '#9499A3', 'zerolinecolor': '#9499A3'},
#   'xaxis': {'gridcolor': '#9499A3', 'zerolinecolor': '#9499A3'}}}

# %%
cf.set_config_file(theme="solar")
titanic.iplot(kind='scatter',y='age', x='fare',  mode='markers', xTitle='fare', yTitle='age')
# Out:
# <div>                            <div id="e8d07fa7-45c8-4aac-8fe6-093c366d2d2b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
